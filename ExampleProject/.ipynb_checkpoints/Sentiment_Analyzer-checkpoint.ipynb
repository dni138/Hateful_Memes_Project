# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import flair

# %%
def load_data(path):
    data = []
    with open(path) as f:
        for el in f:
            data.append(json.loads(el))
            
    return data

# %%
def run_sentiment_classifier(model, data):
    for datum in data:
        s = flair.data.Sentence(datum['text'])
        model.predict(s)
        datum['sentiment'] = s.labels
        
    return data

# %%
def count_hate(data):
    count_1 = 0
    count_0 = 0
    for el in data:
        if el['label'] == 1:
            count_1 += 1
        else:
            count_0 += 1

    print('Not Hateful: {}'.format(count_0))
    print('Hateful: {}'.format(count_1))

# %%
def count_sentiment(data):
    count_neg = 0
    count_pos = 0
    for el in data:
        if str(el['sentiment'][0]).split(" ")[0] == 'NEGATIVE':
            count_neg += 1
        else:
            count_pos += 1

    print('Negative: {}'.format(count_neg))
    print('Positive: {}'.format(count_pos))

# %%
def write_data(data, filename):
    json.dump(data, filename)

# %%
train_data = load_data('data/train.jsonl')
dev_data = load_data('data/dev.jsonl')
test_data = load_data('data/test.jsonl')

# %%
count_hate(train_data)
# Out:
# Not Hateful: 5450
# Hateful: 3050

# %%
count_hate(dev_data)
# Out:
# Not Hateful: 250
# Hateful: 250

# %%
sentiment_model = flair.models.TextClassifier.load('en-sentiment')
# Out:
# 2020-07-02 16:12:45,361 loading file /Users/nissani/.flair/models/sentiment-en-mix-distillbert.pt

# %%
train_results = run_sentiment_classifier(sentiment_model, train_data)

# %%
dev_results = run_sentiment_classifier(sentiment_model, dev_data)

# %%
count_sentiment(train_data)
# Out:
# Negative: 5103
# Positive: 3397

# %%
count_sentiment(dev_data)
# Out:
# Negative: 281
# Positive: 219

# %%
write_data(train_data, 'train_data.txt')
write_data(dev_data, 'dev_data.txt')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-7c92797c5e4d> in <module>
# ----> 1 write_data(train_data, 'train_data.txt')
#       2 write_data(dev_data, 'dev_data.txt')
#
# <ipython-input-44-d5be6f371302> in write_data(data, filename)
#       1 def write_data(data, filename):
# ----> 2     json.dump(data, filename)
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/json/__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     178     # a debuggability cost
#     179     for chunk in iterable:
# --> 180         fp.write(chunk)
#     181
#     182
#
# AttributeError: 'str' object has no attribute 'write'
