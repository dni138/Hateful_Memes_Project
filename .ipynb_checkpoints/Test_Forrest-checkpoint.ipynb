# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json
import cv2
from fer import FER
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
data = []
with open('data/train.jsonl') as f:
    for el in f:
        data.append(json.loads(el))

# %%
data[0]['img']
# Out:
# 'img/42953.png'

# %%
sample = cv2.imread('/Users/nissani/Desktop/Hateful_Memes_Project/ExampleProject/data/' + data[0]['img'])
sample = cv2.resize(sample, (299,299), interpolation = cv2.INTER_AREA)

# %%
sample = sample[:150, :]

# %%
plt.imshow(sample)

# %%
detector = FER(mtcnn = True, min_face_size = 5)
detector.detect_emotions(sample)
# Out:
# []
