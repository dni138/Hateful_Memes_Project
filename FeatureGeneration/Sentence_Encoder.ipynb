# %%
# %matplotlib inline
# %load_ext ipython_reload
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# Out:
# The ipython_reload extension is already loaded. To reload it, use:
#   %reload_ext ipython_reload
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import torch
import sentence_encoder

# %%
wrapper=sentence_encoder.SentenceTransform()

# %%
results=wrapper.extract_text_features_simple(["kill me","red rum","hitler","love"])

# %% [markdown]
# **For Extracting Embedding Getty TAG Data**

# %%
#THIS IS LARGELY CRAP BUT IT WORKS
# Out:
# 4

# %%
import pandas as pd
import numpy as np

# %%
getty_data_pd=pd.read_csv("../data/cleaned_getty_data.csv",index_col=0)

getty_data_pd = getty_data_pd.replace(np.nan, "", regex=True)

# %%
# Out:
# 9983

# %%
glove_encoder=sentence_encoder.GettySentenceTransform("average_word_embeddings_glove.6B.300d")

# %%
glove_mean_tags=glove_encoder.embed_glove_tags(glove_encoder, getty_data_pd["best_tags"].values,None,len(getty_data_pd))

# %%
best_tags_glove=pd.DataFrame(glove_mean_tags)

# %%
best_tags_glove["src"]=getty_data_pd["src"].values

# %%
#best_tags_glove.to_csv("../data/best_tags_glove.csv")

# %% [markdown]
# **FOR EXTRACTING EMBEDDING GETTY DESCRIPTION**

# %%
reg_encoder=sentence_encoder.GettySentenceTransform("roberta-base-nli-stsb-mean-tokens")

# %%
# Out:
#            caption                                       best_caption
# Unnamed: 0
# 6                            Portrait of a young woman against a wall
# 5                   Various funny man's hunter portraits with shot...
# 9                   A fishing hook on a red cord on white background.
# 9                   Photo of a male mechanic typing on his mobile ...
# 1                     European woman covered in holi festival colours
# ...            ...                                                ...
# 8                                           Successful business team.
# 8                   Photo of young couple in love takes selfie in ...
# 4                                   man portrait on tokyo metro train
# 6                                                       Beijing,China
# 6                   İstanbul, Turkey - February 14, 2018: Paper cu...
#
# [1240 rows x 2 columns]

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
mean_embedding=reg_encoder.embed_mean(reg_encoder,getty_data_pd.sample(n=1000)["best_caption"].values,1000)
# Out:
# WARNING:transformers.tokenization_utils_base:Truncation was not explicitely activated but `max_length` is provided a specific value, please use `truncation=True` to explicitely truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# WARNING:transformers.tokenization_utils_base:Truncation was not explicitely activated but `max_length` is provided a specific value, please use `truncation=True` to explicitely truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# ...

# %%
all_data=reg_encoder.embed_column(reg_encoder,getty_data_pd["best_caption"].values,mean_embedding,len(getty_data_pd))
# Out:
# WARNING:transformers.tokenization_utils_base:Truncation was not explicitely activated but `max_length` is provided a specific value, please use `truncation=True` to explicitely truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# WARNING:transformers.tokenization_utils_base:Truncation was not explicitely activated but `max_length` is provided a specific value, please use `truncation=True` to explicitely truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# ...

# %%
review_for_pd=torch.Tensor(all_data).view((len(getty_data_pd),768))

# %%
caption_roberta_pd=pd.DataFrame(review_for_pd)

# %%
caption_roberta_pd["src"]=getty_data_pd["src"].values

# %%
caption_roberta_pd.to_csv("../data/caption_best_roberta_pd.csv")

# %%
getty_data_pd["src"].values
# Out:
# array([56482, 60183, 43905, ..., 78402,  3968, 15728])
