# %%
import getty_simple_featurizer
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/forrest.xiao/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
wrapper=getty_simple_featurizer.GettySimpleWrapper()

# %%
results=wrapper.get_simple_getty_features()
# Out:
# /Users/forrest.xiao/projects/Hateful_Memes_Project/FeatureGeneration/getty_simple_featurizer.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['color_zscore'] = (df['Color_Score'] - df['Color_Score'].mean())/df['Color_Score'].std(ddof=0)
# /Users/forrest.xiao/projects/Hateful_Memes_Project/FeatureGeneration/getty_simple_featurizer.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
len(results)
# Out:
# 10000

# %%
results.head()
# Out:
#       id  all_text_freq  train_text_freq  dev_text_freq  test_text_freq  \
# 0  42953              1              1.0            NaN             NaN
# 1  23058              1              1.0            NaN             NaN
# 2  13894              4              2.0            2.0             NaN
# 3  37408              1              1.0            NaN             NaN
# 4  82403              1              1.0            NaN             NaN
#
#    tags_race  tags_disability  tags_religion  tags_sexual_orientation  \
# 0       True            False          False                    False
# 1       True            False          False                    False
# 2      False            False          False                    False
# 3       True            False          False                    False
# 4      False            False          False                    False
#
#    tags_violence  ...  tags_gender  tags_animals  text_race  text_disability  \
# ...
